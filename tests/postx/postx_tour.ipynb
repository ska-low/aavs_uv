# %%
import numpy as np
import pylab as plt
from aa_uv.io import hdf5_to_uvx
from aa_uv.postx import ApertureArray
from aa_uv.utils import get_test_data

test_data =  {
    'aavs2': (get_test_data('aavs2/correlation_burst_100_20211113_14447_0.hdf5'),
              get_test_data('aavs2/correlation_burst_204_20211113_14653_0.hdf5')),
    'aavs3': (get_test_data('aavs3/correlation_burst_100_20240107_19437_0.hdf5'),
              get_test_data('aavs3/correlation_burst_204_20240107_19437_0.hdf5')),
    'eda2':  (get_test_data('eda2/correlation_burst_100_20211211_14167_0.hdf5'),
              get_test_data('eda2/correlation_burst_204_20211211_14373_0.hdf5')),
}

# %%
uvx = hdf5_to_uvx(test_data['aavs2'][0], telescope_name='aavs2')
aa = ApertureArray(uvx)
# Out:
# 2024-07-11 13:10:28.593 | INFO     | aa_uv.io.to_uvx:load_observation_metadata:39 - Using internal config aavs2
# /Users/daniel.price/Data/aavs_uv/src/aa_uv/datamodel/uvx.py:184: FutureWarning: Setting the location attribute post initialization will be disallowed in a future version of Astropy. Instead you should set the location when creating the Time object. In the future, this will raise an AttributeError.
#   t.location = eloc
# 2024-07-11 13:10:28.977 | INFO     | aa_uv.datamodel.uvx:create_visibility_array:211 - Conjugating data
# 2024-07-11 13:10:28.981 | WARNING  | aa_uv.io.to_uvx:hdf5_to_uvx:183 - Could not find expected keys in observation_info
# 2024-07-11 13:10:28.981 | WARNING  | aa_uv.io.to_uvx:hdf5_to_uvx:185 - <KeysViewHDF5 []>

# %% [markdown]
# ### Module overview

# %%
aa.plotting
# Out:
# <Aperture Array module: plotting>
# A class for plotting utilties.
#
#     Provides the following functions:
#     plot_corr_matrix()
#     plot_corr_matrix_4pol()
#     plot_antennas()
#     plot_uv_dist_amp()

# %%
aa.coords
# Out:
# <Aperture Array module: coords>
# Coordinate utils.
#
#     Provides the following:
#         get_sun() - Get the position of the sun as a SkyCoord
#         get_zenith() - Get the zenith as a SkyCoord
#         get_alt_az() - Get the alt/az of a given SkyCoord
#         generate_phase_vector() - Generate a phase vector toward a given SkyCoord

# %%
aa.calibration
# Out:
# <Aperture Array module: calibration>
# ApertureArray Calibration module.
#
#     Provides the following sub-modules:
#     holography - self-holography techniques
#     stefcal - calibration based on stefcal approach

# %%
aa.calibration.holography
# Out:
# <Aperture Array module: holography>
# A class version of the above jishnu-cal holography routines.
#
#     Provides the following functions:
#     set_cal_src() - set the reference source
#     run_phasecal() - run jishnu_phasecal
#     run_selfholo() - run jishnu_selfholo
#     plot_aperture() - plot aperture illumination (run_selfholo must be run first)
#     plot_aperture_xy() - plot aperture illumination, 2x2 grid of X and Y mag + phs
#     plot_phasecal_iterations() - shows iteration STD plot
#     plot_farfield_beam_pattern() - plot cuts through the farfield electric-field pattern (power)

# %%
aa.calibration.stefcal
# Out:
# <module 'aa_uv.postx.calibration.stefcal' from '/Users/daniel.price/Data/aavs_uv/src/aa_uv/postx/calibration/stefcal.py'>

# %%
aa.simulation
# Out:
# <Aperture Array module: simulation>
# Simulate visibilities using matvis.
#
#     Provides the following:
#         sim_vis_pointsrc(): Simulate visibilities from point source dictionary
#         sim_vis_gsm(): Simulate visibilites using pygdsm sky model
#         orthview_gsm(): View observed diffuse sky model (Orthographic)
#         mollview_gsm(): View observed diffuse sky model (Mollview)

# %%
aa.imaging
# Out:
# <Aperture Array module: imaging>
# ApertureArray Imaging module.
#
#     Provides the following functions:
#     make_image()   - Make a 2D all-sky image (orthographic)
#     make_healpix() - Make a healpix all-sky image

# %%
aa.viewer
# Out:
# <Aperture Array module: All Sky Viewer>
# An all-sky imager based on matplotlib imshow with WCS support.
#
#     Provides the following:
#         orthview() - Plot all-sky image in Orthographic projection
#         mollview() - Plot all-sky image using healpy Mollview
#         load_labels() - Load dictionary of sky coordinates as labels
#         get_pixel() - get pixel ID for a given skycoord
#         write_fits() - write to FITS file
#         orthview_gsm() - orthview plot observed Global diffuse sky model using pygdsm
#         mollview_gsm() - mollview plot observed Global diffuse sky model using pygdsm

# %% [markdown]
# ## aa.plotting

# %%
aa.plotting
# Out:
# <Aperture Array module: plotting>
# A class for plotting utilties.
#
#     Provides the following functions:
#     plot_corr_matrix()
#     plot_corr_matrix_4pol()
#     plot_antennas()
#     plot_uv_dist_amp()

# %%
aa.plotting.plot_antennas()

# %%
aa.plotting.plot_corr_matrix()

# %%
aa.plotting.plot_corr_matrix_4pol()

# %%
aa.plotting.plot_uvdist_amp(sfunc=np.log)

# %% [markdown]
# ## aa.coords

# %%
aa.coords
# Out:
# <Aperture Array module: coords>
# Coordinate utils.
#
#     Provides the following:
#         get_sun() - Get the position of the sun as a SkyCoord
#         get_zenith() - Get the zenith as a SkyCoord
#         get_alt_az() - Get the alt/az of a given SkyCoord
#         generate_phase_vector() - Generate a phase vector toward a given SkyCoord

# %%
aa.coords.get_sun()
# Out:
# <SkyCoord (GCRS: obstime=1636776048.6806436, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, AU)
#     (228.25268613, -17.9225986, 0.98962721)>

# %%
aa.coords.get_zenith()
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (229.0520918, -26.62561233)>

# %%
from astropy.coordinates import SkyCoord
sc = SkyCoord(150, 45, unit=('deg', 'deg'))

aa.coords.get_alt_az(sc)
# Out:
# <SkyCoord (AltAz: obstime=1636776048.6806436, location=(-2559301.90974769, 5095070.36573217, -2848888.27966852) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     (314.8186907, -11.34691515)>

# %%
# Generates per-antenna phase weights
phs_vec = aa.coords.generate_phase_vector(aa.coords.get_sun())

# %%
img = aa.imaging.make_image()
aa.viewer.orthview(img)

# %%
cal = np.outer(phs_vec, phs_vec)

# %%
aa.set_cal(cal)

# %%
#TODO: FIX
#img = aa.imaging.make_image(vis='cal')
#aa.viewer.orthview(img)

# %% [markdown]
# ## aa.calibration
#
# ## aa.calibration.holography

# %%
aa.calibration.holography
# Out:
# <Aperture Array module: holography>
# A class version of the above jishnu-cal holography routines.
#
#     Provides the following functions:
#     set_cal_src() - set the reference source
#     run_phasecal() - run jishnu_phasecal
#     run_selfholo() - run jishnu_selfholo
#     plot_aperture() - plot aperture illumination (run_selfholo must be run first)
#     plot_aperture_xy() - plot aperture illumination, 2x2 grid of X and Y mag + phs
#     plot_phasecal_iterations() - shows iteration STD plot
#     plot_farfield_beam_pattern() - plot cuts through the farfield electric-field pattern (power)

# %%
aa.calibration.holography.set_cal_src(aa.coords.get_sun())

holo_dict = aa.calibration.holography.run_selfholo(vis='data')
print(holo_dict.keys())
# Out:
# 2024-07-11 10:01:14.447 | INFO     | aa_uv.postx.calibration.holography:jishnu_selfholo:222 - Generating vis matrix: data
# dict_keys(['beam_corr', 'aperture_img', 'meas_corr', 'lmn_grid', 'vis_matrix', 'aperture_size', 'n_pix', 'oversample_factor'])

# %%
aa.calibration.holography.plot_aperture(plot_type='mag', annotate=True)

# %%
aa.calibration.holography.plot_aperture(plot_type='phs', phs_range=(-45, 45), annotate=True)

# %%
cal = aa.calibration.holography.run_phasecal()

#TODO: Fix report_flagged_antennas()
#aa.calibration.holography.report_flagged_antennas()
# Out:
# 2024-07-11 10:01:18.285 | INFO     | aa_uv.postx.calibration.holography:jishnu_phasecal:307 - Iter 2: Iteration phase std minima reached, breaking

# %%
cal
# Out:
# UVXAntennaCal(telescope='aavs2', method='jishnu_phasecal', cal=<xarray.DataArray (frequency: 1, antenna: 256, polarization: 2)>
# array([[[ 0.9992217 +3.94461118e-02j,  0.998956  -4.56824489e-02j],
#         [ 0.99990565+1.37347067e-02j,  0.9965477 -8.30219463e-02j],
#         [ 0.9691075 -2.46638939e-01j,  0.9942203 +1.07358761e-01j],
#         [ 0.9973258 +7.30840787e-02j,  0.96608037+2.58241743e-01j],
#         [ 0.99695605-7.79656991e-02j,  0.9582917 +2.85791844e-01j],
#         [ 0.99386346-1.10613890e-01j,  0.99762934+6.88158646e-02j],
#         [ 0.99656427+8.28223675e-02j,  0.        +0.00000000e+00j],
#         [ 0.97244257+2.33142644e-01j,  0.9972104 -7.46431276e-02j],
#         [ 0.9985055 +5.46527989e-02j,  0.9953497 +9.63271558e-02j],
#         [ 0.9960569 +8.87161195e-02j,  0.99977636+2.11474653e-02j],
#         [ 0.99119437-1.32415250e-01j,  0.9946855 -1.02960296e-01j],
#         [ 0.99756837-6.96941167e-02j,  0.99999994+3.20558640e-04j],
#         [ 0.9533797 +3.01773399e-01j,  0.9963927 +8.48619789e-02j],
#         [ 0.9999283 +1.19781131e-02j,  0.9969418 -7.81468824e-02j],
#         [ 0.9732095 +2.29920179e-01j,  0.834953  +5.50321162e-01j],
#         [ 0.97986585+1.99656650e-01j,  0.999671  -2.56487094e-02j],
#         [ 0.9987212 +5.05573191e-02j,  0.80646944+5.91275752e-01j],
#         [ 0.99794406+6.40919283e-02j,  0.998814  +4.86884229e-02j],
#         [ 0.98934823+1.45567909e-01j,  0.89103997+4.53924865e-01j],
#         [ 0.99926203+3.84088680e-02j,  0.99712986-7.57101253e-02j],
# ...
#         [ 0.9923559 +1.23408943e-01j,  0.9326748 +3.60718489e-01j],
#         [ 0.9746573 +2.23703444e-01j,  0.9839906 +1.78220257e-01j],
#         [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#         [ 0.9997935 -2.03196071e-02j,  0.99021477+1.39551967e-01j],
#         [ 0.9999979 +2.03079660e-03j,  0.9890581 +1.47526830e-01j],
#         [ 0.9962437 -8.65934938e-02j,  0.99827653-5.86861856e-02j],
#         [ 0.99266946-1.20860845e-01j,  0.99106187-1.33403078e-01j],
#         [ 0.9577085 -2.87740231e-01j,  0.9976353 +6.87298775e-02j],
#         [ 0.9446615 +3.28046620e-01j,  0.9994582 +3.29144262e-02j],
#         [ 0.9626703 -2.70676732e-01j,  0.99307525-1.17480479e-01j],
#         [ 0.99149954-1.30109861e-01j,  0.9949215 -1.00654446e-01j],
#         [ 0.99801093-6.30411431e-02j,  0.9906854 -1.36170387e-01j],
#         [ 0.9999016 +1.40299713e-02j,  0.9872951 -1.58897445e-01j],
#         [ 0.9997444 +2.26076581e-02j,  0.9943632 -1.06027737e-01j],
#         [ 0.999983  -5.81586454e-03j,  0.9998811 -1.54200848e-02j],
#         [ 0.99586916-9.08002704e-02j,  0.97682506-2.14039087e-01j],
#         [ 0.9757537 +2.18871653e-01j,  0.9963239 -8.56661797e-02j],
#         [ 0.9826428 -1.85507208e-01j,  0.9531973 -3.02348733e-01j],
#         [ 0.9999222 +1.24724498e-02j,  0.98552704+1.69518560e-01j]]],
#       dtype=complex64)
# Coordinates:
#   * polarization  (polarization) <U1 'X' 'Y'
#   * antenna       (antenna) object 'Ant061' 'Ant063' ... 'Ant020' 'Ant019'
#   * frequency     (frequency) float64 7.812e+07
# Attributes:
#     description:  Boolean flags for antenna. 0=unflagged (good), 1=flagged (b..., flags=<xarray.DataArray (frequency: 1, antenna: 256, polarization: 2)>
# array([[[False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
# ...
#         [False, False],
#         [False, False],
#         [False, False],
#         [ True,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False]]])
# Coordinates:
#   * polarization  (polarization) <U1 'X' 'Y'
#   * antenna       (antenna) object 'Ant061' 'Ant063' ... 'Ant020' 'Ant019'
#   * frequency     (frequency) float64 7.812e+07
# Attributes:
#     description:  Per-antenna calibration coefficients, provenance={'jishnu_phasecal': {'phs_cal': masked_array(
#   data=[[(0.999221682548523+0.039446111768484116j),
#          (0.998956024646759-0.04568244889378548j)],
#         [(0.9999056458473206+0.013734706677496433j),
#          (0.9965476989746094-0.08302194625139236j)],
#         [(0.9691075086593628-0.2466389387845993j),
#          (0.9942203164100647+0.10735876113176346j)],
#         [(0.9973257780075073+0.07308407872915268j),
#          (0.966080367565155+0.25824174284935j)],
#         [(0.9969560503959656-0.07796569913625717j),
#          (0.9582917094230652+0.2857918441295624j)],
#         [(0.9938634634017944-0.11061388999223709j),
#          (0.9976293444633484+0.06881586462259293j)],
#         [(0.9965642690658569+0.08282236754894257j), --],
#         [(0.9724425673484802+0.2331426441669464j),
#          (0.9972103834152222-0.07464312762022018j)],
#         [(0.9985054731369019+0.05465279892086983j),
#          (0.9953497052192688+0.09632715582847595j)],
#         [(0.9960569143295288+0.08871611952781677j),
#          (0.9997763633728027+0.021147465333342552j)],
#         [(0.9911943674087524-0.13241524994373322j),
#          (0.9946854710578918-0.10296029597520828j)],
#         [(0.9975683689117432-0.06969411671161652j),
#          (0.9999999403953552+0.00032055863994173706j)],
#         [(0.9533796906471252+0.30177339911460876j),
#          (0.9963927268981934+0.08486197888851166j)],
#         [(0.9999282956123352+0.01197811309248209j),
#          (0.9969418048858643-0.07814688235521317j)],
#         [(0.9732095003128052+0.2299201786518097j),
#          (0.8349530100822449+0.5503211617469788j)],
#         [(0.9798658490180969+0.1996566504240036j),
#          (0.9996709823608398-0.025648709386587143j)],
#         [(0.998721182346344+0.050557319074869156j),
#          (0.8064694404602051+0.5912757515907288j)],
#         [(0.9979440569877625+0.06409192830324173j),
#          (0.9988139867782593+0.04868842288851738j)],
#         [(0.9893482327461243+0.1455679088830948j),
#          (0.8910399675369263+0.45392486453056335j)],
#         [(0.9992620348930359+0.03840886801481247j),
#          (0.9971298575401306-0.07571012526750565j)],
#         [(0.9999962449073792+0.0027138888835906982j),
#          (0.9954519867897034+0.09526512026786804j)],
#         [(0.9931298494338989+0.11701705306768417j),
#          (0.9905182123184204-0.13738122582435608j)],
#         [(0.9903849363327026-0.13833875954151154j),
#          (0.9863248467445374-0.1648128479719162j)],
#         [(0.9999545812606812-0.009533182717859745j),
#          (0.9941205978393555+0.10827866941690445j)],
#         [(0.9999457001686096-0.010424925945699215j),
#          (0.9854379892349243-0.17003507912158966j)],
#         [(0.969886302947998+0.2435580939054489j),
#          (0.9618522524833679+0.2735695242881775j)],
#         [(0.9779044389724731-0.20905233919620514j),
#          (0.9953373670578003-0.09645462781190872j)],
#         [(0.9709141850471497-0.23942787945270538j),
#          (0.982321560382843-0.18720100820064545j)],
#         [(0.9793362617492676+0.20223863422870636j),
#          (0.8673816919326782+0.49764350056648254j)],
#         [(0.9895803332328796-0.14398162066936493j),
#          (0.9956777691841125-0.09287505596876144j)],
#         [(0.9903885126113892-0.13831302523612976j),
#          (0.971607506275177-0.23659878969192505j)],
#         [(0.9923955798149109-0.12309016287326813j),
#          (0.9492805004119873-0.3144306540489197j)],
#         [(0.9966492652893066-0.08179367333650589j),
#          (0.9800193905830383+0.19890187680721283j)],
#         [(0.9999993443489075-0.0012270479928702116j),
#          (0.9543831944465637-0.29858437180519104j)],
#         [(0.9691687226295471+0.24639800190925598j),
#          (0.9954102039337158-0.09570038318634033j)],
#         [(0.8688804507255554+0.4950219690799713j),
#          (0.9889562129974365+0.14820744097232819j)],
#         [--, --],
#         [--, --],
#         [--, --],
#         [(0.9710599184036255-0.23883594572544098j),
#          (0.8697533011436462-0.49348685145378113j)],
#         [(0.996656060218811+0.08171094208955765j),
#          (0.988039493560791-0.15420104563236237j)],
#         [(0.9848779439926147-0.1732497364282608j),
#          (0.9840288162231445-0.17800916731357574j)],
#         [--, --],
#         [(0.9939095973968506+0.11019819229841232j),
#          (0.9220025539398193+0.3871837854385376j)],
#         [(0.9933576583862305+0.11506795138120651j),
#          (0.9552845358848572+0.2956881821155548j)],
#         [(0.9975728988647461-0.06962999701499939j),
#          (0.938417375087738+0.34550371766090393j)],
#         [(0.9994993805885315-0.03163716942071915j),
#          (0.9884946346282959-0.15125572681427002j)],
#         [(0.9978995323181152+0.0647805780172348j),
#          (0.9983528256416321+0.057372044771909714j)],
#         [(0.7753612399101257-0.6315180063247681j),
#          (0.5791350603103638-0.8152315616607666j)],
#         [(0.30359622836112976-0.9528008103370667j),
#          (0.7166775465011597-0.6974047422409058j)],
#         [(0.9924007058143616+0.12304791063070297j),
#          (0.9996019601821899-0.028212109580636024j)],
#         [(0.9994145035743713+0.03421207144856453j),
#          (0.9840685725212097-0.17778924107551575j)],
#         [(0.9777457118034363+0.20979344844818115j),
#          (0.9346057176589966+0.35568559169769287j)],
#         [(0.9768937230110168+0.21372546255588531j),
#          (0.9306556582450867+0.36589619517326355j)],
#         [(0.9526189565658569+0.3041662573814392j),
#          (0.9963093400001526-0.08583557605743408j)],
#         [(0.9747010469436646+0.22351239621639252j),
#          (0.9960638284683228-0.08864013850688934j)],
#         [(0.9987326264381409-0.05033012107014656j),
#          (0.9933761358261108+0.1149078980088234j)],
#         [(0.9999735355377197-0.007269688416272402j),
#          (0.9749249219894409-0.22253422439098358j)],
#         [(0.9997400045394897+0.022804036736488342j),
#          (0.9946297407150269+0.10349712520837784j)],
#         [(0.9969831705093384+0.07761756330728531j),
#          (0.935374915599823+0.3536577820777893j)],
#         [(0.9902418851852417+0.13935932517051697j),
#          (0.9992840886116028+0.037831928580999374j)],
#         [(0.9921828508377075-0.12479202449321747j),
#          (0.9698852300643921+0.24356268346309662j)],
#         [(0.9998724460601807-0.015973253175616264j),
#          (0.9929708242416382-0.11835967749357224j)],
#         [(0.9539090394973755+0.3000958561897278j),
#          (0.994322657585144+0.10640683025121689j)],
#         [(0.9999738335609436-0.0072284177877008915j),
#          (0.9851188659667969+0.17187419533729553j)],
#         [(0.979423999786377+0.2018134444952011j),
#          (0.992564857006073+0.12171701341867447j)],
#         [--, --],
#         [--, --],
#         [(0.9959144592285156+0.09030142426490784j),
#          (0.9796639084815979+0.20064561069011688j)],
#         [(0.9911351203918457+0.13285766541957855j),
#          (0.9948863983154297-0.10100054740905762j)],
#         [(0.9955716729164124-0.09400583058595657j),
#          (0.9966681599617004+0.08156317472457886j)],
#         [(0.9998795986175537+0.015513896010816097j),
#          (0.9954699277877808+0.09507697075605392j)],
#         [(0.9990487694740295+0.04360707849264145j),
#          (0.9994253516197205+0.03389783203601837j)],
#         [(0.9978017807006836-0.06626971065998077j),
#          (0.9980137348175049+0.06299766898155212j)],
#         [(0.998341977596283-0.05756086856126785j),
#          (0.9894778728485107+0.14468418061733246j)],
#         [(0.9920592308044434+0.12577104568481445j),
#          (0.9972779154777527-0.07373352348804474j)],
#         [(0.9911572933197021+0.1326928436756134j),
#          (0.9762908816337585+0.21646273136138916j)],
#         [(0.9913070201873779+0.1315689980983734j),
#          (0.9745423793792725+0.2242034673690796j)],
#         [(0.9908924698829651-0.13465601205825806j),
#          (0.9904412627220154-0.13793471455574036j)],
#         [(0.9996336102485657-0.027067340910434723j),
#          (0.9994210600852966+0.03402215614914894j)],
#         [(0.9997099041938782+0.024087682366371155j),
#          (0.9243747591972351-0.3814854621887207j)],
#         [(0.9923558831214905+0.12340894341468811j),
#          (0.9326748251914978+0.3607184886932373j)],
#         [(0.9746572971343994+0.22370344400405884j),
#          (0.9839906096458435+0.1782202571630478j)],
#         [--, --],
#         [(0.999793529510498-0.020319607108831406j),
#          (0.9902147650718689+0.13955196738243103j)],
#         [(0.9999979138374329+0.002030796604231j),
#          (0.9890580773353577+0.1475268304347992j)],
#         [(0.9962437152862549-0.08659349381923676j),
#          (0.9982765316963196-0.058686185628175735j)],
#         [(0.9926694631576538-0.12086084485054016j),
#          (0.9910618662834167-0.13340307772159576j)],
#         [(0.957708477973938-0.28774023056030273j),
#          (0.9976353049278259+0.06872987747192383j)],
#         [(0.9446614980697632+0.32804661989212036j),
#          (0.9994581937789917+0.0329144261777401j)],
#         [(0.9626703262329102-0.27067673206329346j),
#          (0.9930752515792847-0.11748047918081284j)],
#         [(0.9914995431900024-0.13010986149311066j),
#          (0.9949215054512024-0.10065444558858871j)],
#         [(0.9980109333992004-0.06304114311933517j),
#          (0.9906854033470154-0.1361703872680664j)],
#         [(0.9999015927314758+0.014029971323907375j),
#          (0.9872950911521912-0.15889744460582733j)],
#         [(0.9997444152832031+0.022607658058404922j),
#          (0.9943631887435913-0.10602773725986481j)],
#         [(0.999983012676239-0.0058158645406365395j),
#          (0.9998810887336731-0.015420084819197655j)],
#         [(0.9958691596984863-0.09080027043819427j),
#          (0.9768250584602356-0.21403908729553223j)],
#         [(0.9757537245750427+0.21887165307998657j),
#          (0.9963238835334778-0.08566617965698242j)],
#         [(0.9826428294181824-0.18550720810890198j),
#          (0.9531973004341125-0.3023487329483032j)],
#         [(0.9999222159385681+0.01247244980186224j),
#          (0.9855270385742188+0.16951856017112732j)]],
#   mask=[[False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [ True,  True],
#         [ True,  True],
#         [ True,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [ True,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [ True, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [ True, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [ True,  True],
#         [ True,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [ True,  True],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False],
#         [False, False]],
#   fill_value=(1e+20+0j),
#   dtype=complex64), 'n_iter': 3, 'phs_std': array([0.33875145, 0.13464099, 0.13117955])}, 'aa_uv_config': {'aa_uv': '2.0.0', 'astropy': '6.1.0', 'numpy': '1.26.4', 'pyuvdata': '0.1.dev5900+gb6b31f2', 'xarray': '2023.11.0', 'pandas': '2.1.3', 'h5py': '3.9.0', 'erfa': '2.0.1.1'}})

# %%
aa.set_cal(cal)
holo_dict = aa.calibration.holography.run_selfholo(vis='cal')
aa.calibration.holography.plot_aperture(plot_type='phs', phs_range=(-45, 45))
# Out:
# 2024-07-11 10:01:27.176 | INFO     | aa_uv.postx.calibration.holography:jishnu_selfholo:222 - Generating vis matrix: cal

# %%
aa.calibration.holography.plot_farfield_beam_pattern()

# %% [markdown]
# ## aa.imaging and aa.viewer

# %%
aa.imaging
# Out:
# <Aperture Array module: imaging>
# ApertureArray Imaging module.
#
#     Provides the following functions:
#     make_image()   - Make a 2D all-sky image (orthographic)
#     make_healpix() - Make a healpix all-sky image

# %%
aa.viewer
# Out:
# <Aperture Array module: All Sky Viewer>
# An all-sky imager based on matplotlib imshow with WCS support.
#
#     Provides the following:
#         orthview() - Plot all-sky image in Orthographic projection
#         mollview() - Plot all-sky image using healpy Mollview
#         load_labels() - Load dictionary of sky coordinates as labels
#         get_pixel() - get pixel ID for a given skycoord
#         write_fits() - write to FITS file
#         orthview_gsm() - orthview plot observed Global diffuse sky model using pygdsm
#         mollview_gsm() - mollview plot observed Global diffuse sky model using pygdsm

# %%
img = aa.imaging.make_image(vis='cal')
hpx = aa.imaging.make_healpix(vis='data')

# %%
plt.figure(figsize=(3*2,3*2))
for ii in range(4):
    aa.viewer.orthview(img,
                       sfunc=np.log,
                       overlay_srcs=True, colorbar=True, pol_idx=ii,
                       subplot_id=(2,2,ii+1),
                       title=f"Pol {aa.uvx.data.polarization[ii].values}")
plt.tight_layout()

# %%
aa.viewer.mollview(hpx, overlay_srcs=True)

# %%
aa.viewer.orthview_gsm()

# %%
aa.simulation.mollview_gsm()

# %%
sc = aa.coords.get_sun()
print(aa.viewer.get_pixel(sc))

NSIDE = 128
print(aa.viewer.get_pixel_healpix(NSIDE, sc))
# Out:
# (74, 65)
# 19660
